# %% [markdown]
# ### Data overview
#
# Get some initial statistics of the data we are working with. This information can be used to explain further processing steps eg. removing outliers, filling nan etc.

# %%
import pandas as pd


multi_df = pd.read_csv("../Datasets/Multivariate_dist_exercise_data.csv") 
hovs_df = pd.read_csv("../Datasets/HovsoreData_Sonic_100m_2004-2013.csv")
ml_input_df = pd.read_excel("../Datasets/ML_ExampleDataSet.xlsx",sheet_name="InputVariables")
ml_loadres_df = pd.read_excel("../Datasets/ML_ExampleDataSet.xlsx",sheet_name="LoadResults")

# %%
# Get Latex table with:
# May need some formating for floats, and not all columns migth be relevant but a good general overview

print(multi_df.describe().to_latex())
print(hovs_df.describe().to_latex())
print(hovs_df.describe().to_latex())
print(ml_loadres_df.describe().to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
#  & Wsp & SigmaU & Rho \\
# \midrule
# count & 429729.000000 & 429729.000000 & 429729.000000 \\
# mean & 8.840375 & 0.728670 & 1.224956 \\
# std & 4.565496 & 0.449738 & 0.029967 \\
# min & 0.493000 & 0.005177 & 1.080936 \\
# 25% & 5.396300 & 0.405845 & 1.204751 \\
# 50% & 8.438300 & 0.640530 & 1.224985 \\
# 75% & 11.648900 & 0.958940 & 1.245110 \\
# max & 39.766600 & 8.017437 & 1.353002 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrrrrrrrr}
# \toprule
#  & Timestamp & Wsp & TI & TI,detrend & MeanDir & MeanTrigDir & StdDir & MinDir & MaxDir \\
# \midrule
# count & 439512.000000 & 439510.000000 & 439510.000000 & 439510.000000 & 439510.000000 & 439510.000000 & 439512.000000 & 439512.000000 & 439512.000000 \\
# mean & 200872475606.567749 & 21669.104393 & 0.099536 & 0.089781 & 204.064613 & 204.269321 & 10.415410 & 170.158478 & 230.565691 \\
# ...

# %%
multi_df.describe()
# Out:
#                  Wsp         SigmaU            Rho
# count  429729.000000  429729.000000  429729.000000
# mean        8.840375       0.728670       1.224956
# std         4.565496       0.449738       0.029967
# min         0.493000       0.005177       1.080936
# 25%         5.396300       0.405845       1.204751
# 50%         8.438300       0.640530       1.224985
# 75%        11.648900       0.958940       1.245110
# max        39.766600       8.017437       1.353002

# %%
hovs_df.describe()
# Out:
#           Timestamp           Wsp             TI     TI,detrend  \
# count  4.395120e+05  4.395100e+05  439510.000000  439510.000000
# mean   2.008725e+11  2.166910e+04       0.099536       0.089781
# std    2.543683e+08  4.646644e+05       0.316100       0.314036
# min    2.004100e+11  4.924000e-01       0.000000       0.000000
# 25%    2.006123e+11  5.212100e+00       0.052000       0.046900
# 50%    2.009022e+11  8.355000e+00       0.075000       0.068600
# 75%    2.011050e+11  1.161790e+01       0.109400       0.099400
# max    2.013083e+11  1.000000e+07      77.247700      77.246700
#
#              MeanDir    MeanTrigDir         StdDir         MinDir  \
# count  439510.000000  439510.000000  439512.000000  439512.000000
# mean      204.064613     204.269321      10.415410     170.158478
# std        88.127242      92.557876      24.917371      97.622079
# min         1.900300       0.000400       0.000000      -4.215200
# ...

# %%
ml_input_df.describe()
# Out:
#           Sample_No            U       SigmaU        Alpha        MannL  \
# count   9980.000000  9980.000000  9980.000000  9980.000000  9980.000000
# mean    5000.246894    11.009614     1.905174     0.311300   146.257740
# std     2887.008931     4.943964     0.980303     0.467314    75.678372
# min        1.000000     4.000000     0.100000    -0.650000     7.500000
# 25%     2501.750000     6.830865     1.077384    -0.031264    83.029318
# 50%     4997.500000    10.164359     1.879242     0.278029   147.966547
# 75%     7501.250000    14.508335     2.684152     0.592120   211.558874
# max    10000.000000    24.767981     4.970584     2.020959   274.936336
#
#          MannGamma  VeerDeltaPhi
# count  9980.000000   9980.000000
# mean      2.997934     12.107198
# std       1.155050     14.638828
# min       1.000000    -22.250000
# 25%       1.998224      0.709894
# 50%       2.997268      9.477963
# 75%       3.997678     22.178587
# max       4.998634     45.934710

# %%
ml_loadres_df.describe()
# Out:
#             PointNo  Tower_top_fore_aft_M_x  Tower_top_side2side_M_y  \
# count   9980.000000             9980.000000              9980.000000
# mean    5000.246894             4613.299348               866.858387
# std     2887.008931             2298.162901               427.580958
# min        1.000000              247.950473                56.502695
# 25%     2501.750000             2736.587835               501.750277
# 50%     4997.500000             4472.494517               857.199540
# 75%     7501.250000             6270.550961              1199.036319
# max    10000.000000            13441.726895              2217.583227
#
#        Tower_base_fore_aft_M_x  Tower_base_side2side_M_y  Yaw_moment_M_z  \
# count              9980.000000               9980.000000     9980.000000
# mean              28594.324504              16170.943941     9433.747660
# std               17753.126331              11812.544173     4916.393439
# ...
